# %% [markdown]
# #Logical Functions & Lookup

# %% [markdown]
# 1. Write a formula to check if the marks in cell are greater than or equal to 40. If yes, return , otherwise
# .
# B2 "Pass"
# "Fail
# - =IF(B2>=40,"Pass","Fail")
#
# 2.  company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not .
# - =IF(AND(B2>40000,C2>=90),"Bonus","No Bonus")
#
# 3. rite a nested IF formula:
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fail
# - =IF(B2>=90,"A",IF(B2>=75,"B",IF(B2>=50,"C","Fail")))
#
# 4. nd the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
# - =VLOOKUP("E103", A2:C5, 3, FALSE)
# > VLOOKUP use hota hai jab:
#
# - Lookup value (EmpID) first column me ho
# Aur hume uske right side se data (Department) chahiye
#
# 5. company has set the following commission structure for its sales team:
# - =VLOOKUP(45000, A2:B5, 2, TRUE)
# > ₹45,000 does not exactly exist
#  So VLOOKUP returns the closest lower value → 20,000 → 10%
#
# 6. The HR department maintains the following leave records of employees:onus or not .
# - If Leaves Taken > Leaves Allowed → "Exceeded"
# Otherwise → "OK"
# > =IF(A2>B2,"Exceeded","OK")
#
# 7. Find the salary of EmpID = E105 using INDEX-MATCH Function
# - =INDEX(B2:B5, MATCH("E105", A2:A5, 0))
# >- N NNMATCH finds the position of E105 in EmpID column
# >- INDEX returns the salary from that position
# - Why INDEX-MATCH?
# >- More flexible than VLOOKUP
# >- Works even if lookup column is not on the left
#
# 8. Use the XLOOKUP function to find the Department of the employee with Emp ID = E303.
# -=XLOOKUP("E303", A2:A5, C2:C5)
# >- XLOOKUP searches E303 in EmpID column
# >- Returns corresponding value from Department column
# - Why XLOOKUP?
# >- Works both left & right
# >- No need for column number (like VLOOKUP)
# >- More accurate & easy to use
